# %%
import pandas as pd

# Create dataset
data = [
    # Billing
    ["Payment failed", "My payment was declined while making a purchase", "Billing"],
    ["Refund pending", "I requested a refund but have not received it", "Billing"],
    ["Wrong invoice", "The amount shown on my invoice is incorrect", "Billing"],
    ["Double charged", "I was charged twice for the same order", "Billing"],
    ["Payment issue", "I am unable to complete my payment", "Billing"],
    ["Invoice request", "Please send me the invoice for my purchase", "Billing"],
    ["Transaction failed", "My transaction failed but money was deducted", "Billing"],
    ["Subscription payment", "My subscription payment is not going through", "Billing"],

    # Technical
    ["Cannot login", "I cannot log in to my account", "Technical"],
    ["Website error", "The website shows an error when I open it", "Technical"],
    ["Password reset", "The password reset link is not working", "Technical"],
    ["Application crash", "The mobile application crashes when I open it", "Technical"],
    ["System not working", "The system is not working properly", "Technical"],
    ["Page loading", "The webpage is stuck and keeps loading", "Technical"],
    ["Server error", "I am getting a server error", "Technical"],
    ["Account access", "I cannot access my account", "Technical"],

    # HR
    ["Leave request", "I want to apply for annual leave", "HR"],
    ["Salary question", "I have a question about my salary", "HR"],
    ["Employee details", "I need to update my employee information", "HR"],
    ["Leave balance", "Please tell me my remaining leave balance", "HR"],
    ["Joining date", "I need information about my joining date", "HR"],
    ["HR policy", "Where can I find the employee HR policies", "HR"],
    ["Payslip request", "I need a copy of my latest payslip", "HR"],
    ["Interview status", "I want to know the status of my interview", "HR"],

    # General
    ["Product information", "I need more information about your product", "General"],
    ["Business hours", "What are your working hours", "General"],
    ["Contact information", "How can I contact your company", "General"],
    ["Company information", "Please provide information about your company", "General"],
    ["Feedback", "I would like to provide feedback about your service", "General"],
    ["Service details", "Can you explain the services you provide", "General"],
    ["Location information", "Where is your office located", "General"],
    ["Product availability", "Is this product currently available", "General"]
]

# %%
# Convert to DataFrame
df = pd.DataFrame(data, columns=["subject", "body", "category"])

# %%
df.head()
# Out:
#           subject                                             body category
# 0  Payment failed  My payment was declined while making a purchase  Billing
# 1  Refund pending    I requested a refund but have not received it  Billing
# 2   Wrong invoice      The amount shown on my invoice is incorrect  Billing
# 3  Double charged           I was charged twice for the same order  Billing
# 4   Payment issue               I am unable to complete my payment  Billing

# %%
df.to_csv("tickets.csv", index=False)

# %%
df
# Out:
#                  subject                                               body  \
# 0         Payment failed    My payment was declined while making a purchase
# 1         Refund pending      I requested a refund but have not received it
# 2          Wrong invoice        The amount shown on my invoice is incorrect
# 3         Double charged             I was charged twice for the same order
# 4          Payment issue                 I am unable to complete my payment
# 5        Invoice request         Please send me the invoice for my purchase
# 6     Transaction failed       My transaction failed but money was deducted
# 7   Subscription payment       My subscription payment is not going through
# 8           Cannot login                      I cannot log in to my account
# 9          Website error          The website shows an error when I open it
# 10        Password reset             The password reset link is not working
# ...
